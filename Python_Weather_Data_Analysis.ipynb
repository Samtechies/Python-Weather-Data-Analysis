# %% [markdown]
# <a href="https://colab.research.google.com/github/Samtechies/Python-Weather-Data-Analysis/blob/main/Python_Weather_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **THE WEATHER DATASET**
#
#
# -  The Weather Dataset is a time-series data set with per-hour information about the weather conditions at a particular location. It records:
# 1.  Temperature
# 2.  Dew Point Temperature
# 3.  Relative Humidity
# 4.  Wind Speed
# 5.  Visibility
# 6.  Pressure
# 7.  Conditions

# %%
import pandas as pd

# %%
data = pd.read_csv("/content/Project+1+-+Weather+Dataset (1).csv")

# %%
data
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %% [markdown]
# -  Checking for Summary Statistics

# %%
data.describe()
# Out:
#             Temp_C  Dew Point Temp_C    Rel Hum_%  Wind Speed_km/h  \
# count  8784.000000       8784.000000  8784.000000      8784.000000
# mean      8.798144          2.555294    67.431694        14.945469
# std      11.687883         10.883072    16.918881         8.688696
# min     -23.300000        -28.500000    18.000000         0.000000
# 25%       0.100000         -5.900000    56.000000         9.000000
# 50%       9.300000          3.300000    68.000000        13.000000
# 75%      18.800000         11.800000    81.000000        20.000000
# max      33.000000         24.400000   100.000000        83.000000
#
#        Visibility_km    Press_kPa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %% [markdown]
# -  Dsiplaying Index, Columns, and Data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %% [markdown]
# **ANALYZING DATA FRAMES**

# %%
data.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
data.shape
# Out:
# (8784, 8)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
data.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
data['Weather'].unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
data['Weather'].nunique()
# Out:
# 50

# %%
data.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
data.count()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
data['Date/Time'].value_counts()
# Out:
# Date/Time
# 1/1/2012 0:00       1
# 9/1/2012 3:00       1
# 8/31/2012 21:00     1
# 8/31/2012 22:00     1
# 8/31/2012 23:00     1
#                    ..
# 5/1/2012 17:00      1
# 5/1/2012 16:00      1
# 5/1/2012 15:00      1
# 5/1/2012 14:00      1
# 12/31/2012 23:00    1
# Name: count, Length: 8784, dtype: int64

# %%
data['Weather'].value_counts()
# Out:
# Weather
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %% [markdown]
# -  **IN-DEPTH ANALYSIS OF THE WEATHER DATASET**

# %% [markdown]
# Q1. Finding all the unique "Wind Speed" values in the Data

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
data['Wind Speed_km/h'].unique()  #All unique values
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2])

# %%
data['Wind Speed_km/h'].nunique()
# Out:
# 34

# %% [markdown]
# Q2. Finding the number of times when the "Weather is exactly Clear"

# %%
# View of the data set
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
# Using Value Count
data['Weather'].value_counts()  #Answer = 1326
# Out:
# Weather
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %%
# By Filtering
data[data.Weather == 'Clear']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
# Using groupby
data.groupby('Weather').get_group('Clear')
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %% [markdown]
# Q3. Finding the number of times when the "Wind Speed was exactly 4km/h"

# %%
data['Wind Speed_km/h'].value_counts()
# Out:
# Wind Speed_km/h
# 9     830
# 11    791
# 13    735
# 15    719
# 7     677
# 17    666
# 19    616
# 6     609
# 20    496
# 4     474
# 22    439
# 24    374
# 0     309
# 26    242
# 28    205
# 30    161
# 32    139
# 33     85
# 35     53
# 37     45
# 39     24
# 41     22
# 44     14
# 43     13
# 48     13
# 46     11
# 52      7
# 57      5
# 50      4
# 2       2
# 83      1
# 70      1
# 63      1
# 54      1
# Name: count, dtype: int64

# %%
# By Filtering
data[data['Wind Speed_km/h'] == 4]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 96       1/5/2012 0:00    -8.8             -11.7         79                4
# 101      1/5/2012 5:00    -7.0              -9.5         82                4
# 146      1/7/2012 2:00    -8.1             -11.1         79                4
# ...                ...     ...               ...        ...              ...
# 8768   12/31/2012 8:00    -8.6             -10.3         87                4
# 8769   12/31/2012 9:00    -8.1              -9.6         89                4
# 8770  12/31/2012 10:00    -7.4              -8.9         89                4
# 8772  12/31/2012 12:00    -5.8              -7.5         88                4
# 8773  12/31/2012 13:00    -4.6              -6.6         86                4
#
#       Visibility_km  Press_kPa       Weather
# ...

# %% [markdown]
# Q4. Finding out Null Values in the Data

# %%
data.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
data.notnull().sum()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %% [markdown]
# Q5. Renaming The Column name 'Weather' of the dataframe to 'Weather Condition'

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog
# 1            8.0     101.24     Fog

# %%
data.rename(columns = {'Weather' : 'Weather Condition'}, inplace = True)
data.head(2)
# Without inplace = 2 renames only for one instance
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %% [markdown]
# Q6. What is the mean 'Visibility'?

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %%
data['Visibility_km'].mean()
# Out:
# 27.664446721311478

# %% [markdown]
# Q7. Standard Deviation of the 'Pressure' in the Data

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %%
data['Press_kPa'].std()
# Out:
# 0.8440047459486483

# %% [markdown]
# Q8. Variance of 'Relative Humidity' in this data

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %%
data['Rel Hum_%'].var()
# Out:
# 286.24855019850196

# %% [markdown]
# Q9. Finding all instances when 'Snow' was recorded

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %%
data['Weather Condition'].value_counts()
# Out:
# Weather Condition
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# ...

# %%
# By Filtering
data[data['Weather Condition'] == 'Snow']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 55       1/3/2012 7:00   -14.0             -19.5         63               19
# 84      1/4/2012 12:00   -13.7             -21.7         51               11
# 86      1/4/2012 14:00   -11.3             -19.0         53                7
# 87      1/4/2012 15:00   -10.2             -16.3         61               11
# 88      1/4/2012 16:00    -9.4             -15.5         61               13
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
# Finding all instances where snow was recorded
# Using str.contains
data[data['Weather Condition'].str.contains('Snow')].head(50)
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 41   1/2/2012 17:00    -2.1              -9.5         57               22
# 44   1/2/2012 20:00    -5.6             -13.4         54               24
# 45   1/2/2012 21:00    -5.8             -12.8         58               26
# 47   1/2/2012 23:00    -7.4             -14.1         59               17
# 48    1/3/2012 0:00    -9.0             -16.0         57               28
# 50    1/3/2012 2:00   -10.5             -15.8         65               22
# 51    1/3/2012 3:00   -11.3             -18.7         54               33
# 53    1/3/2012 5:00   -12.9             -19.1         60               22
# 54    1/3/2012 6:00   -13.3             -19.3         61               19
# 55    1/3/2012 7:00   -14.0             -19.5         63               19
# 84   1/4/2012 12:00   -13.7             -21.7         51               11
# 86   1/4/2012 14:00   -11.3             -19.0         53                7
# ...

# %%
# Bottom 50
data[data['Weather Condition'].str.contains('Snow')].tail(50)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 8680  12/27/2012 16:00    -4.5              -6.2         88               37
# 8681  12/27/2012 17:00    -4.2              -5.9         88               32
# 8682  12/27/2012 18:00    -4.0              -5.7         88               28
# 8683  12/27/2012 19:00    -3.9              -5.6         88               26
# 8684  12/27/2012 20:00    -3.7              -5.3         89               37
# 8685  12/27/2012 21:00    -3.7              -4.8         92               24
# 8686  12/27/2012 22:00    -3.8              -4.6         94               20
# 8687  12/27/2012 23:00    -4.0              -5.6         89               24
# 8688   12/28/2012 0:00    -4.2              -5.7         89               19
# 8689   12/28/2012 1:00    -4.4              -6.6         85               15
# 8690   12/28/2012 2:00    -4.3              -6.3         86               11
# ...

# %% [markdown]
# Q10. Finding all instances when 'Wind Speed is above 24' and 'Visbility is 25'

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %%
data[(data['Wind Speed_km/h'] > 24) & (data['Visibility_km'] == 25)]  # Filtering
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 23      1/1/2012 23:00     5.3               2.0         79               30
# 24       1/2/2012 0:00     5.2               1.5         77               35
# 25       1/2/2012 1:00     4.6               0.0         72               39
# 26       1/2/2012 2:00     3.9              -0.9         71               32
# 27       1/2/2012 3:00     3.7              -1.5         69               33
# ...                ...     ...               ...        ...              ...
# 8705  12/28/2012 17:00    -8.6             -12.0         76               26
# 8753  12/30/2012 17:00   -12.1             -15.8         74               28
# 8755  12/30/2012 19:00   -13.4             -16.5         77               26
# 8759  12/30/2012 23:00   -12.1             -15.1         78               28
# 8760   12/31/2012 0:00   -11.1             -14.4         77               26
#
# ...

# %% [markdown]
# Q11. What is the mean value of each column against each 'Weather Condition' ?

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %%
# Using Groupby
data.groupby('Weather Condition').mean(numeric_only=True)
# Out:
#                                             Temp_C  Dew Point Temp_C  \
# Weather Condition
# Clear                                     6.825716          0.089367
# Cloudy                                    7.970544          2.375810
# Drizzle                                   7.353659          5.504878
# Drizzle,Fog                               8.067500          7.033750
# Drizzle,Ice Pellets,Fog                   0.400000         -0.700000
# Drizzle,Snow                              1.050000          0.150000
# Drizzle,Snow,Fog                          0.693333          0.120000
# Fog                                       4.303333          3.159333
# Freezing Drizzle                         -5.657143         -8.000000
# Freezing Drizzle,Fog                     -2.533333         -4.183333
# Freezing Drizzle,Haze                    -5.433333         -8.000000
# Freezing Drizzle,Snow                    -5.109091         -7.072727
# ...

# %% [markdown]
# Q12. What is the Minimum & Maximum value of each column against each 'Weather Condition' ?

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %%
data.groupby('Weather Condition').min()
# Out:
#                                                 Date/Time  Temp_C  \
# Weather Condition
# Clear                                      1/11/2012 1:00   -23.3
# Cloudy                                     1/1/2012 17:00   -21.4
# Drizzle                                   1/23/2012 21:00     1.1
# Drizzle,Fog                               1/23/2012 20:00     0.0
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00     0.4
# Drizzle,Snow                             12/17/2012 15:00     0.9
# Drizzle,Snow,Fog                         12/18/2012 21:00     0.3
# Fog                                         1/1/2012 0:00   -16.0
# Freezing Drizzle                          1/13/2012 10:00    -9.0
# Freezing Drizzle,Fog                        1/1/2012 2:00    -6.4
# Freezing Drizzle,Haze                      2/1/2012 11:00    -5.8
# Freezing Drizzle,Snow                      1/13/2012 3:00    -8.3
# Freezing Fog                               1/22/2012 6:00   -19.0
# ...

# %%
# Maximum
data.groupby('Weather Condition').max()
# Out:
#                                                 Date/Time  Temp_C  \
# Weather Condition
# Clear                                       9/9/2012 5:00    32.8
# Cloudy                                     9/9/2012 23:00    30.5
# Drizzle                                    9/30/2012 3:00    18.8
# Drizzle,Fog                                9/30/2012 2:00    19.9
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00     0.4
# Drizzle,Snow                             12/19/2012 18:00     1.2
# Drizzle,Snow,Fog                          12/22/2012 3:00     1.1
# Fog                                        9/22/2012 0:00    20.8
# Freezing Drizzle                            2/1/2012 5:00    -2.3
# Freezing Drizzle,Fog                      12/10/2012 5:00    -0.3
# Freezing Drizzle,Haze                      2/1/2012 13:00    -5.0
# Freezing Drizzle,Snow                      3/2/2012 12:00    -3.3
# Freezing Fog                               3/17/2012 6:00    -0.1
# ...

# %% [markdown]
# Q13. Show all the Records Where Weather Condition is Fog

# %%
data['Weather Condition'] == 'Fog'
# Out:
# 0        True
# 1        True
# 2       False
# 3       False
# 4        True
#         ...
# 8779    False
# 8780    False
# 8781    False
# 8782    False
# 8783    False
# Name: Weather Condition, Length: 8784, dtype: bool

# %%
data[data['Weather Condition'] == 'Fog'].head(50)
# Out:
#             Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0       1/1/2012 0:00    -1.8              -3.9         86                4
# 1       1/1/2012 1:00    -1.8              -3.7         87                4
# 4       1/1/2012 4:00    -1.5              -3.3         88                7
# 5       1/1/2012 5:00    -1.4              -3.3         87                9
# 6       1/1/2012 6:00    -1.5              -3.1         89                7
# 7       1/1/2012 7:00    -1.4              -3.6         85                7
# 8       1/1/2012 8:00    -1.4              -3.6         85                9
# 9       1/1/2012 9:00    -1.3              -3.1         88               15
# 10     1/1/2012 10:00    -1.0              -2.3         91                9
# 11     1/1/2012 11:00    -0.5              -2.1         89                7
# 12     1/1/2012 12:00    -0.2              -2.0         88                9
# ...

# %% [markdown]
# Q14. Find all Instances when 'Weather is Clear' or 'Visibility is above 40'

# %%
data.head(2)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather Condition
# 0            8.0     101.24               Fog
# 1            8.0     101.24               Fog

# %%
data[(data['Weather Condition'] == 'Clear') | (data['Visibility_km'] > 40)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 106     1/5/2012 10:00    -6.0             -10.0         73               17
# 107     1/5/2012 11:00    -5.6             -10.2         70               22
# 108     1/5/2012 12:00    -4.7              -9.6         69               20
# 109     1/5/2012 13:00    -4.4              -9.7         66               26
# ...                ...     ...               ...        ...              ...
# 8749  12/30/2012 13:00   -12.4             -16.2         73               37
# 8750  12/30/2012 14:00   -11.8             -16.1         70               37
# 8751  12/30/2012 15:00   -11.3             -15.6         70               32
# 8752  12/30/2012 16:00   -11.4             -15.5         72               26
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
# ...

# %%
data[(data['Weather Condition'] == 'Clear') | (data['Visibility_km'] > 40)].head(50)
# Out:
#            Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67    1/3/2012 19:00   -16.9             -24.8         50               24
# 106   1/5/2012 10:00    -6.0             -10.0         73               17
# 107   1/5/2012 11:00    -5.6             -10.2         70               22
# 108   1/5/2012 12:00    -4.7              -9.6         69               20
# 109   1/5/2012 13:00    -4.4              -9.7         66               26
# 110   1/5/2012 14:00    -5.1             -10.7         65               22
# 111   1/5/2012 15:00    -4.3             -12.0         55               26
# 114   1/5/2012 18:00    -7.1             -14.4         56               11
# 115   1/5/2012 19:00    -9.2             -15.4         61                7
# 116   1/5/2012 20:00    -9.8             -15.7         62                9
# 117   1/5/2012 21:00    -9.0             -14.8         63               13
# ...

# %% [markdown]
# Q15. Find all Instances when:
# -  A. 'Weather os Clear' and 'Relative Humidity is greater than 50' or
# -  B.  'Visibility is above 40'

# %%
# Solution for A
data[(data['Weather Condition'] == 'Clear') & (data['Rel Hum_%'] > 50) | (data['Visibility_km'] > 40)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 106     1/5/2012 10:00    -6.0             -10.0         73               17
# 107     1/5/2012 11:00    -5.6             -10.2         70               22
# 108     1/5/2012 12:00    -4.7              -9.6         69               20
# 109     1/5/2012 13:00    -4.4              -9.7         66               26
# 110     1/5/2012 14:00    -5.1             -10.7         65               22
# ...                ...     ...               ...        ...              ...
# 8749  12/30/2012 13:00   -12.4             -16.2         73               37
# 8750  12/30/2012 14:00   -11.8             -16.1         70               37
# 8751  12/30/2012 15:00   -11.3             -15.6         70               32
# 8752  12/30/2012 16:00   -11.4             -15.5         72               26
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
# ...
